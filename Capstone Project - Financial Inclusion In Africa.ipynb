# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Sklearn libraries
from sklearn.model_selection import train_test_split     # data separation
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report, confusion_matrix      # confusion_matrix

from sklearn import metrics 

#cross validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# Algorithm model

from sklearn.linear_model import LogisticRegression      # Loggistic Regression

from sklearn.naive_bayes import ComplementNB             # Naive Bayes

from sklearn.neighbors import KNeighborsClassifier       # Algorithm KNN

from sklearn import preprocessing                        # Normalize

# warning

import warnings

# %%
import datetime

# %%
dset=pd.read_csv('C:/Users/Santosh/Documents/MS/Capstone Project/Zindi Africa/Train1.csv')

# %%
dset.shape
# Out:
# (23524, 13)

# %%
dset.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
#Describe the data set 
dset.describe()
# Out:
#                year  household_size  age_of_respondent
# count  23524.000000    23524.000000       23524.000000
# mean    2016.975939        3.797483          38.805220
# std        0.847371        2.227613          16.520569
# min     2016.000000        1.000000          16.000000
# 25%     2016.000000        2.000000          26.000000
# 50%     2017.000000        3.000000          35.000000
# 75%     2018.000000        5.000000          49.000000
# max     2018.000000       21.000000         100.000000

# %%
# Check if any NULL values are there in our dataset

#dset[dset.isnull().any(axis=1)]
dset.isnull().values.any()
# Out:
# False

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
# If respondent has a Bank account then 1 else 0 for No
dset["bank_account"] = np.where(dset["bank_account"] == "Yes", 1, 0)

# If Location type is Urban then 1 else 0 for Rural
dset["location_type"] = np.where(dset["location_type"] == "Urban", 1, 0)

# If respondent has mobile access then 1 else 0 for No
dset["cellphone_access"] = np.where(dset["cellphone_access"] == "Yes", 1, 0)

# If respondent is Male then 1 else 0 for Female
dset["gender_of_respondent"] = np.where(dset["gender_of_respondent"] == "Male", 1, 0)

# %%
print(dset['relationship_with_head'].value_counts())
# Out:
# Head of Household      12831
# Spouse                  6520
# Child                   2229
# Parent                  1086
# Other relative           668
# Other non-relatives      190
# Name: relationship_with_head, dtype: int64

# %%
# Change the values as below to convert values to int
# Head of Household      1
# Spouse                 2
# Child                  3
# Parent                 4
# Other relative         5
# Other non-relatives    6

dset["relationship_with_head"] = np.where(dset["relationship_with_head"] == "Head of Household", 1, dset["relationship_with_head"])
dset["relationship_with_head"] = np.where(dset["relationship_with_head"] == "Spouse", 2, dset["relationship_with_head"])
dset["relationship_with_head"] = np.where(dset["relationship_with_head"] == "Child", 3, dset["relationship_with_head"])
dset["relationship_with_head"] = np.where(dset["relationship_with_head"] == "Parent", 4, dset["relationship_with_head"])
dset["relationship_with_head"] = np.where(dset["relationship_with_head"] == "Other relative", 5, dset["relationship_with_head"])
dset["relationship_with_head"] = np.where(dset["relationship_with_head"] == "Other non-relatives", 6, dset["relationship_with_head"])

# %%
print(dset['marital_status'].value_counts())
# Out:
# Married/Living together    10749
# Single/Never Married        7983
# Widowed                     2708
# Divorced/Seperated          2076
# Dont know                      8
# Name: marital_status, dtype: int64

# %%
# Change the values as below to convert values to int
# Married/Living together  1
# Single/Never Married     2
# Widowed                  3
# Divorced/Seperated       4
# Dont know                5


dset["marital_status"] = np.where(dset["marital_status"] == "Married/Living together", 1, dset["marital_status"])
dset["marital_status"] = np.where(dset["marital_status"] == "Single/Never Married", 2, dset["marital_status"])
dset["marital_status"] = np.where(dset["marital_status"] == "Widowed", 3, dset["marital_status"])
dset["marital_status"] = np.where(dset["marital_status"] == "Divorced/Seperated", 4, dset["marital_status"])
dset["marital_status"] = np.where(dset["marital_status"] == "Dont know", 5, dset["marital_status"])

# %%
print(dset['education_level'].value_counts())
# Out:
# Primary education                  12791
# No formal education                 4515
# Secondary education                 4223
# Tertiary education                  1157
# Vocational/Specialised training      803
# Other/Dont know/RTA                   35
# Name: education_level, dtype: int64

# %%
# Change the values as below to convert values to int
# Primary education                  1
# No formal education                2 
# Secondary education                3
# Tertiary education                 4
# Vocational/Specialised training    5
# Other/Dont know/RTA                6


dset["education_level"] = np.where(dset["education_level"] == "Primary education", 1, dset["education_level"])
dset["education_level"] = np.where(dset["education_level"] == "No formal education", 2, dset["education_level"])
dset["education_level"] = np.where(dset["education_level"] == "Secondary education", 3, dset["education_level"])
dset["education_level"] = np.where(dset["education_level"] == "Tertiary education", 4, dset["education_level"])
dset["education_level"] = np.where(dset["education_level"] == "Vocational/Specialised training", 5, dset["education_level"])
dset["education_level"] = np.where(dset["education_level"] == "Other/Dont know/RTA", 6, dset["education_level"])

# %%
print(dset['job_type'].value_counts())
# Out:
# Self employed                   6437
# Informally employed             5597
# Farming and Fishing             5441
# Remittance Dependent            2527
# Other Income                    1080
# Formally employed Private       1055
# No Income                        627
# Formally employed Government     387
# Government Dependent             247
# Dont Know/Refuse to answer       126
# Name: job_type, dtype: int64

# %%
# Change the values as below to convert values to int
# Self employed                   1
# Informally employed             2
# Farming and Fishing             3
# Remittance Dependent            4
# Other Income                    5
# Formally employed Private       6
# No Income                       7
# Formally employed Government    8
# Government Dependent            9
# Dont Know/Refuse to answer      10


dset["job_type"] = np.where(dset["job_type"] == "Self employed", 1, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Informally employed", 2, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Farming and Fishing", 3, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Remittance Dependent", 4, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Other Income", 5, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Formally employed Private", 6, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "No Income", 7, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Formally employed Government", 8, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Government Dependent", 9, dset["job_type"])
dset["job_type"] = np.where(dset["job_type"] == "Dont Know/Refuse to answer", 10, dset["job_type"])

# %%
print(dset['country'].value_counts())
# Out:
# Rwanda      8735
# Tanzania    6620
# Kenya       6068
# Uganda      2101
# Name: country, dtype: int64

# %%
# Change the values as below to convert values to int
# Rwanda            1
# Tanzania          2
# Kenya             3
# Uganda            4

dset["country"] = np.where(dset["country"] == "Rwanda", 1, dset["country"])
dset["country"] = np.where(dset["country"] == "Tanzania", 2, dset["country"])
dset["country"] = np.where(dset["country"] == "Kenya", 3, dset["country"])
dset["country"] = np.where(dset["country"] == "Uganda", 4, dset["country"])

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  int32
#  4   location_type           23524 non-null  int32
#  5   cellphone_access        23524 non-null  int32
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  int32
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int32(4), int64(3), object(6)
# memory usage: 2.0+ MB

# %%
# Now to understand the correlation in this data set we will use the heat map to visualize it.
plt.figure(figsize=(20, 10))
heatmap = sns.heatmap(dset.corr(), vmin=0, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
# Out:
# C:\Users\Santosh\AppData\Local\Temp\ipykernel_19320\2624594652.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(dset.corr(), vmin=0, vmax=1, annot=True, cmap='BrBG')
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
Categorical = ['country', 'bank_account', 'location_type', 'cellphone_access', 'gender_of_respondent', 'education_level']
i = 0
while i<6 :
   
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,3,1)
    sns.countplot(x = Categorical[i] , data = dset)
    i += 1
 
    if i==7:
        break
        
    plt.subplot(1,3,2)
    sns.countplot(x = Categorical[i] , data = dset)
    i += 1
    
    plt.subplot(1,3,3)
    sns.countplot(x = Categorical[i] , data = dset)
    i += 1
    
    plt.show()

# %%
# boxplot for continuous columns

continuous = [ 'age_of_respondent']
i = 0
while i<1 :
    
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,3,1)
    sns.boxplot(x = continuous[i] , data = dset)
    i += 1
    
    
    plt.show()

# %%
df = pd.DataFrame(dset)

# %%
dset = dset[dset['age_of_respondent']<80]

# %%
# boxplot for continuous columns

continuous = [ 'age_of_respondent']
i = 0
while i<1 :
    
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,3,1)
    sns.boxplot(x = continuous[i] , data = dset)
    i += 1
    
    
    plt.show()

# %%
Categorical = ['education_level']
i = 0
while i<1 :
   
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,1,1)
    sns.countplot(x = Categorical[i] , data = dset)
    i += 1
    plt.show()

# %%
dset_Rawanda = dset[dset['country'] == 1]
dset_Tanzania = dset[dset['country'] == 2]
dset_Kenya = dset[dset['country'] == 3]
dset_Uganda = dset[dset['country'] == 4]

# %%
Categorical = ['bank_account']
i = 0
while i<1 :
   
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,1,1)
    sns.countplot(x = Categorical[i] , data = dset_Kenya)
    i += 1
    plt.show()

# %%
Categorical = ['bank_account']
i = 0
while i<1 :
   
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,1,1)
    sns.countplot(x = Categorical[i] , data = dset_Kenya)
    i += 1
    plt.show()

# %%
Categorical = ['bank_account']
i = 0
while i<1 :
   
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,1,1)
    sns.countplot(x = Categorical[i] , data = dset_Tanzania)
    i += 1
    plt.show()

# %%
Categorical = ['bank_account']
i = 0
while i<1 :
   
    fig = plt.figure(figsize = [20,5])
    
    plt.subplot(1,1,1)
    sns.countplot(x = Categorical[i] , data = dset_Uganda)
    i += 1
    plt.show()

# %%
dset
# Out:
#       country  year       uniqueid  bank_account  location_type  \
# 0           3  2018     uniqueid_1             1              0
# 1           3  2018     uniqueid_2             0              0
# 2           3  2018     uniqueid_3             1              1
# 3           3  2018     uniqueid_4             0              0
# 4           3  2018     uniqueid_5             0              1
# ...       ...   ...            ...           ...            ...
# 23519       4  2018  uniqueid_2113             0              0
# 23520       4  2018  uniqueid_2114             0              0
# 23521       4  2018  uniqueid_2115             0              0
# 23522       4  2018  uniqueid_2116             0              1
# 23523       4  2018  uniqueid_2117             0              0
#
#        cellphone_access  household_size  age_of_respondent  \
# 0                     1               3                 24
# 1                     0               5                 70
# ...

# %%
dset['uniqueid'] = dset['uniqueid'].str.split('_').str[1]

# %%
for i in range(0, len(dset.columns)):
    dset.iloc[:,i] = pd.to_numeric(dset.iloc[:,i], errors='ignore')
# Out:
# C:\Users\Santosh\AppData\Local\Temp\ipykernel_19320\2097708702.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dset.iloc[:,i] = pd.to_numeric(dset.iloc[:,i], errors='ignore')

# %%
final_dataset = dset

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23061 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23061 non-null  int64
#  1   year                    23061 non-null  int64
#  2   uniqueid                23061 non-null  int64
#  3   bank_account            23061 non-null  int32
#  4   location_type           23061 non-null  int32
#  5   cellphone_access        23061 non-null  int32
#  6   household_size          23061 non-null  int64
#  7   age_of_respondent       23061 non-null  int64
#  8   gender_of_respondent    23061 non-null  int32
#  9   relationship_with_head  23061 non-null  int64
#  10  marital_status          23061 non-null  int64
#  11  education_level         23061 non-null  int64
#  12  job_type                23061 non-null  int64
# dtypes: int32(4), int64(9)
# memory usage: 2.1 MB

# %%
# Now again we will plot the correlation matrix using heatmap with updated dataset
plt.figure(figsize=(20, 10))
heatmap = sns.heatmap(final_dataset.corr(), vmin=0, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Check the percentage of the population having bank account or not

(final_dataset['bank_account'].value_counts()/final_dataset['bank_account'].count())*100
# Out:
# 0    85.828889
# 1    14.171111
# Name: bank_account, dtype: float64

# %%
# Split dataset into feature variable and target variable

x = final_dataset.drop('bank_account' , axis = 1)
y = final_dataset["bank_account"]

# %%
# Split the datset into 80:20 ratio for train and test
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1)

# %%
logreg = LogisticRegression()
logreg.fit(x_train,y_train.ravel())
y_pred = logreg.predict(x_test)
# Out:
# C:\Users\Santosh\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# plot

fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
plt.plot(fpr,tpr,label = "data 1")
plt.legend(loc = 4)
plt.show()

# %%
y_pred_proba = logreg.predict_proba(x_test)[::,1]

fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
plt.plot(fpr,tpr,label="data 1")
plt.legend(loc=4)
plt.show()

# %%
# confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[3868,   68],
#        [ 515,  162]], dtype=int64)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.873618035985259

# %%
# confusion matrix


cm = confusion_matrix(y_test, y_pred)
fig , ax = plt.subplots(figsize=(8,8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels=('predicted 0s' , 'predicted 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels=('Actual 0s' , 'Actual 1s'))
ax.set_ylim(1.5,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i , cm[i,j] , ha='center' , va='center' , color ='red')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train.ravel())
y_pred = rfc.predict(x_test)

# %%
# plot

fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
plt.plot(fpr,tpr,label = "data 1")
plt.legend(loc = 4)
plt.show()

# %%
y_pred_proba = logreg.predict_proba(x_test)[::,1]

fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
plt.plot(fpr,tpr,label="data 1")
plt.legend(loc=4)
plt.show()

# %%
# confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[3804,  132],
#        [ 438,  239]], dtype=int64)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8764361586819857

# %%
# confusion matrix


cm = confusion_matrix(y_test, y_pred)
fig , ax = plt.subplots(figsize=(8,8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels=('predicted 0s' , 'predicted 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels=('Actual 0s' , 'Actual 1s'))
ax.set_ylim(1.5,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i , cm[i,j] , ha='center' , va='center' , color ='red')
plt.show()

# %%
# Create Decision Tree classifer object
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion="entropy", max_depth=10)

# Train Decision Tree Classifer
dtc = dtc.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = dtc.predict(x_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8699327986126165

# %%
# plot

fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
plt.plot(fpr,tpr,label = "data 2")
plt.legend(loc = 4)
plt.show()

# %%
y_pred_proba = dtc.predict_proba(x_test)[::,1]

fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
plt.plot(fpr,tpr,label="data 2")
plt.legend(loc=4)
plt.show()

# %%
# confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[3817,  119],
#        [ 481,  196]], dtype=int64)

# %%
# confusion matrix


cm = confusion_matrix(y_test, y_pred)
fig , ax = plt.subplots(figsize=(8,8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels=('predicted 0s' , 'predicted 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels=('Actual 0s' , 'Actual 1s'))
ax.set_ylim(1.5,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i , cm[i,j] , ha='center' , va='center' , color ='red')
plt.show()
